# %%
import argparse
import time
import torch
from Models import get_model
from Process import *
import torch.nn.functional as F
from Optim import CosineWithRestarts
from Batch import create_masks
import pdb
import dill as pickle
import argparse
from Models import get_model
from Beam import beam_search
from nltk.corpus import wordnet
from torch.autograd import Variable
import re
from Batch import nopeak_mask
import math
import numpy as np
from pathlib import Path
import subprocess
from nltk.translate.bleu_score import sentence_bleu, corpus_bleu
from Models import Transformer
from translation.translator import Translator
from translation.query import *
from sklearn.feature_extraction.text import TfidfVectorizer
os.chdir("/mnt/nfs/work1/allan/smsarwar/material/pytorch_transformer/")

# %%
def tokenizer(text):  # create a tokenizer function
    return text.split()

def create_fields(opt):
    #print("loading tokenizers...")
    SRC = pickle.load(open(f'{opt.load_vocab}/SRC.pkl', 'rb'))
    TRG = pickle.load(open(f'{opt.load_vocab}/TRG.pkl', 'rb'))
    return (SRC, TRG)

def evaluate():
    # Check current working directory.
    # retval = os.getcwd()
    os.chdir("CLEF-ENG-ML/")
    p = subprocess.Popen(
        '/cm/shared/apps/java/jdk1.8.0_191/bin/java -cp target/lib/*:target/CLEF-ENG-ML-1.0-SNAPSHOT.jar rabflair.flair.myBatchSearch',
        shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT)
    
    line = p.stdout.readlines()[0]
    line_splitted = line.decode().split()
    mAP = float(line_splitted[3])
    os.chdir("../")
    print("MAP:\t" + str(mAP))
    
parser = argparse.ArgumentParser()
#If we are working on small dataset
small = 0
#If we want to activate relevance based training
relevance_training = 1
if small==1:
    parser.add_argument('-src_data', type=str, default='data/italian_small.txt')
    parser.add_argument('-trg_data', type=str, default='data/english_small.txt')
    parser.add_argument('-trg_data_retrieval', type=str, default='data/english_retrieval.txt')

else:
    parser.add_argument('-src_data', type=str, default='data/italian.txt')
    parser.add_argument('-trg_data', type=str, default='data/english.txt')
    parser.add_argument('-trg_data_retrieval', type=str, default='data/LATIMESTEXT2.txt')

parser.add_argument('-src_lang', type=str, default='it')
parser.add_argument('-trg_lang', type=str, default='en')
parser.add_argument('-no_cuda', action='store_true')
parser.add_argument('-SGDR', action='store_true')
parser.add_argument('-epochs', type=int, default=2)
parser.add_argument('-d_model', type=int, default=200)
parser.add_argument('-n_layers', type=int, default=6)
parser.add_argument('-heads', type=int, default=8)
parser.add_argument('-dropout', type=int, default=0.1)
parser.add_argument('-batchsize', type=int, default=1500)
parser.add_argument('-printevery', type=int, default=100)
parser.add_argument('-lr', type=int, default=0.0001)
parser.add_argument('-load_weights', type=str, default='weights')
parser.add_argument('-load_vocab', type=str, default='clir_it_en')
#parser.add_argument('-load_weights', type=str, default='tiny_train')
parser.add_argument('-create_valset', action='store_true')
parser.add_argument('-max_strlen', type=int, default=80)
parser.add_argument('-floyd', action='store_true')
parser.add_argument('-checkpoint', type=int, default=0)
# Out:
# _StoreAction(option_strings=['-checkpoint'], dest='checkpoint', nargs=None, const=None, default=0, type=<class 'int'>, choices=None, help=None, metavar=None)

# %%
opt = parser.parse_args(args=[])

raw_data = {'trg': [line for line in open(opt.trg_data)]} ###  
raw_data_retrieval = {'trg': [line for line in open(opt.trg_data_retrieval)]}
# print(len(raw_data['trg']))    
# print(len(raw_data_retrieval['trg']))    
# vectorizer_europarl = TfidfVectorizer(use_idf=True)
# vectorizer_europarl.fit_transform(raw_data['trg'])
# tokens_europarl = vectorizer_europarl.get_feature_names()

# vectorizer_clef = TfidfVectorizer(use_idf=True)
# vectorizer_clef.fit_transform(raw_data_retrieval['trg'])
# tokens_clef = vectorizer_clef.get_feature_names()

#idf_values = vectorizer.idf_

# %%
tokens_europarl_dict = {}
tokens_clef_dict = {} 
for line in open(opt.trg_data):
    for token in line.split():
        tokens_europarl_dict.setdefault(token.strip(), 1)

for line in open(opt.trg_data_retrieval):
    for token in line.split():
        tokens_clef_dict.setdefault(token.strip(), 1)

# %%
tokens_europarl = tokens_europarl_dict.keys()
tokens_clef = tokens_clef_dict.keys()
tokens_union = tokens_europarl | tokens_clef
tokens_intersection = tokens_europarl & tokens_clef 
tokens_only_europarl = tokens_europarl - tokens_intersection
tokens_only_clef = tokens_clef - tokens_intersection


print("size of europarl token set")
print(len(tokens_europarl))
print("size of clef token set")
print(len(tokens_clef))
print("size of intersection of the tokens")
print(len(tokens_intersection))
print("size of union of the tokens")
print(len(tokens_union))
print("size of only clef token set")
print(len(tokens_only_clef))
print("size of only europarl token set")
print(len(tokens_only_europarl))


def query_term_vocabulary_distribution(query):
    #print(len(tokens_only_europarl))
    #print(len(tokens_only_clef))
    #print(query)
    
    query = query.strip()
    query_splitted = query.split()
    query_splitted_set = set(query_splitted)
    print (query_splitted_set)
    count_only_europarl = 0.0
    count_only_clef = 0.0
    count_others = 0.0
    count_intersection = 0.0
    for term in query_splitted_set:
        #print (term)
        if term in tokens_only_europarl:
            count_only_europarl+=1
        elif term in tokens_only_clef:
            count_only_clef+=1
            print("clef term\t" + term)
        elif term in tokens_intersection:
            count_intersection+=1
        else:
            count_others+=1
            
    print("count only europarl\t" + str(count_only_europarl))
    print("count only clef\t" + str(count_only_clef))
    print("count intersection\t" + str(count_intersection))
    print("count others\t" + str(count_others))
    
    #print("count only europarl\t" + str(count_only_europarl/len(query_splitted_set)))
    #print("count only clef\t" + str(count_only_clef/len(query_splitted_set)))
    #print("count intersection\t" + str(count_intersection/len(query_splitted_set)))
    #print("count others\t" + str(count_others/len(query_splitted_set)))
# Out:
# size of europarl token set
# 77441
# size of clef token set
# 214767
# size of intersection of the tokens
# 51918
# size of union of the tokens
# 240290
# size of only clef token set
# 162849
# size of only europarl token set
# 25523

# %%
from sklearn.feature_extraction.text import CountVectorizer

print("creating dataset and iterator... ")
print(opt.trg_data)

translation_data = [line for line in open(opt.trg_data)] ###
raw_data = {'trg': translation_data} ###  
raw_data_retrieval = {'trg': [line for line in open(opt.trg_data_retrieval)]}

europarl_dict = {}
clef_dict = {}

for line in open(opt.trg_data): 
    line_splitted = line.split()
    for token in line_splitted: 
        token_stripped = token.strip() 
        if token_stripped in europarl_dict: 
            europarl_dict[token_stripped] = europarl_dict[token_stripped] + 1
        else:
            europarl_dict[token_stripped] = 1

for line in open(opt.trg_data_retrieval): 
    line_splitted = line.split()
    for token in line_splitted: 
        token_stripped = token.strip() 
        if token_stripped in clef_dict: 
            clef_dict[token_stripped] = clef_dict[token_stripped] + 1
        else:
            clef_dict[token_stripped] = 1
# Out:
# creating dataset and iterator...
# data/english.txt

# %%
total_frequency_clef = 0
total_frequency_europarl = 0

for key in europarl_dict.keys():
    total_frequency_europarl+= europarl_dict[key]

for key in clef_dict.keys():
    total_frequency_clef+= clef_dict[key]
print (total_frequency_clef)
print (total_frequency_europarl)
# Out:
# 34613470
# 25134641

# %%
def query_term_distribution(query):
    #print(len(tokens_only_europarl))
    #print(len(tokens_only_clef))
    #print(query)
    
    query = query.strip()
    query_splitted = query.split()
    query_splitted_set = set(query_splitted)
    query_vocab_ditribution = {}
    for term in query_splitted_set:
        europarl_element = 0 
        if term.strip() in europarl_dict: 
            europarl_element = europarl_dict[term.strip()]
        clef_element = 0
        if term.strip() in clef_dict: 
            clef_element = clef_dict[term.strip()]
        
        query_vocab_ditribution[term.strip()] = [europarl_element * 10000 / total_frequency_europarl , clef_element * 10000 / total_frequency_clef]
    europarl = 0.0
    clef = 0.0
    top_europarl = []
    ratio = 0.0
    for key in query_vocab_ditribution.keys():
        europarl= query_vocab_ditribution[key][0]
        clef= query_vocab_ditribution[key][1]
        ratio+= europarl/clef
        top_europarl.append((key, query_vocab_ditribution[key][0], query_vocab_ditribution[key][1]))
        
    top_europarl = sorted(top_europarl, key = lambda x: x[1], reverse=True)
    top_europarl = top_europarl[0:1]        
    return query_vocab_ditribution, ratio/len(query_vocab_ditribution), top_europarl

import torch
import torch.nn as nn
from Layers import EncoderLayer, DecoderLayer
from Embed import Embedder, PositionalEncoder
from Sublayers import Norm
import copy

def get_clones(module, N):
    return nn.ModuleList([copy.deepcopy(module) for i in range(N)])

class Encoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, dropout):
        super().__init__()
        self.N = N
        self.embed = Embedder(vocab_size, d_model)
        self.pe = PositionalEncoder(d_model, dropout=dropout)
        self.layers = get_clones(EncoderLayer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)
    def forward(self, src, mask):
        x = self.embed(src)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x, mask)
        return self.norm(x)

class Decoder(nn.Module):
    def __init__(self, vocab_size, d_model, N, heads, dropout):
        super().__init__()
        self.N = N
        self.embed = Embedder(vocab_size, d_model)
        self.pe = PositionalEncoder(d_model, dropout=dropout)
        self.layers = get_clones(DecoderLayer(d_model, heads, dropout), N)
        self.norm = Norm(d_model)
    def forward(self, trg, e_outputs, src_mask, trg_mask):
        x = self.embed(trg)
        x = self.pe(x)
        for i in range(self.N):
            x = self.layers[i](x, e_outputs, src_mask, trg_mask)
        return self.norm(x)

class Transformer(nn.Module):
    def __init__(self, src_vocab, trg_vocab, d_model, N, heads, dropout):
        super().__init__()
        self.encoder = Encoder(src_vocab, d_model, N, heads, dropout)
        self.decoder = Decoder(trg_vocab, d_model, N, heads, dropout)
        self.out = nn.Linear(d_model, trg_vocab)
    def forward(self, src, trg, src_mask, trg_mask):
        e_outputs = self.encoder(src, src_mask)
        #print("DECODER")
        d_output = self.decoder(trg, e_outputs, src_mask, trg_mask)
        output = self.out(d_output)
        return output

def get_model(opt, src_vocab, trg_vocab):

    assert opt.d_model % opt.heads == 0
    assert opt.dropout < 1

    model = Transformer(src_vocab, trg_vocab, opt.d_model, opt.n_layers, opt.heads, opt.dropout)

    if opt.load_weights is not None:
        print("loading pretrained weights...")
        model.load_state_dict(torch.load(f'{opt.load_weights}/model_weights'))
    else:
        for p in model.parameters():
            if p.dim() > 1:
                nn.init.xavier_uniform_(p)

    if opt.device == 0:
        model = model.cuda()


os.chdir("/mnt/nfs/work1/allan/smsarwar/material/pytorch_transformer/")
opt.device = 0 if opt.no_cuda is False else -1
opt.max_len = 100
CONTEXT_SIZE = 2    
#print(opt)
SRC, TRG = create_fields(opt)
# opt.train = create_dataset(opt, SRC, TRG)
translator = Translator(SRC, TRG)

model_dict = {"N(MT)+":"so_far_best_validation", "NMT":"mw_sum_relevance_translation/model_weights_best_validation", "current":"model_weights", "no_relevance": "so_far_best_validation"}
config = {"model": model_dict["N(MT)+"],  
"source_cat" : False,  #original query concatenated into source
"source_cat_frequency" : 2,  #2 is default, if want to concatenate more increase this value
"target_cat" : False,    #original query concatenated into target
"target_cat_frequency" : 2, 
"query_type" : "squery", 
"galago_query" : False,
"rm" : False,
"rm_weight" : 0.80,
"k" : 1, 
"query_expansion" : False,
"number_of_expansion_terms" : 1, 
"nqueries": 50, 
"verbose": True}


#for rm_weight in np.linspace(0.85, 1, 5):
for rm_weight in [0.5]:
    config['rm_weight'] = rm_weight
    if config["query_expansion"] == False:
        config["rm"] = False

    opt.k = config["k"]

    #model = Transformer(len(SRC.vocab), len(TRG.vocab), opt.d_model, opt.n_layers, opt.heads, opt.dropout, 2)
    model = Transformer(len(SRC.vocab), len(TRG.vocab), opt.d_model, opt.n_layers, opt.heads, opt.dropout)
    #src_vocab, trg_vocab, opt.d_model, opt.n_layers, opt.heads, opt.dropout
    
    model = model.cuda()
    model_str = f'{opt.load_weights}/' + config["model"]   
    model.load_state_dict(torch.load(model_str)) 
    # Order in which queries are put: title, title_description, description
    # load italian queries
    eng_query_dict = translator.load_query_file("CLEF-ENG-ML/index/english/all", "All-eng-tit-final.tsv", "All-eng-tit-des-final-clef.tsv")
    it_query_dict = translator.load_query_file("CLEF-ENG-ML/index/italian", "All-Top-ita-tit-final.txt",
                                    "All-Top-ita-tit-desc-final.txt")
    it_query_tt_dict = translator.load_query_tt("CLEF-ENG-ML/index/italian", "italian_tt_temp.txt")
    translation_file = open(os.path.join("CLEF-ENG-ML/index/english/all", "All-eng-tit-des-final.tsv"), "w")

    sum_percentage_uncovered = 0.0
    clef_term_dict = {}
    nqueries = 0.0
    europarl_vocab = 0.0
    clef_vocab = 0.0
    ratio = 0.0
    for key in sorted(it_query_dict)[0:50]: #config["nqueries"]]:
        opt.text = it_query_dict[key][1]  ###    
        original_query = opt.text 
        #tt_query = it_query_tt_dict[opt.text]     
        opt.text = opt.text.replace("trova", " ")
        opt.text = opt.text.replace("documenti", " ")
        opt.text = opt.text.replace("trovino", " ")    
        opt.text = opt.text.replace("riguardano", " ")        
        if config["source_cat"] == True:
            opt.text = " ".join([original_query] * config["source_cat_frequency"])

        candidate, queries, query_tokens = translator.translate(opt, model, SRC, TRG)     

        if config["query_type"] == "dquery":
            if config["galago_query"] == True:
                candidate = create_galago_query(queries[0], "")
            else:
                candidate = ' '.join(queries[0].keys()) ###    
        else:
            candidate = candidate.lower() 
            if len(candidate) == 0:
                candidate = opt.text
            
        candidate_splitted = candidate.split()        
        
        #print (candidate_splitted)
        window_size = CONTEXT_SIZE * 2 + 1
        
        if len(candidate_splitted) == 0: 
            candidate_splitted = opt.text.split()
        
        while len(candidate_splitted) < window_size:  #if the length of the translation is so small not to fit in a window
            #candidate_splitted+= candidate_splitted[0: (window_size - (len(candidate_splitted)))] 
            candidate_splitted.append(candidate_splitted[0])
            
        #print (candidate_splitted)
        
        
#         tt = torch.LongTensor([[TRG.vocab.stoi[token] for token in candidate_splitted]]).cuda()            

#         data_context_final = []
#         data_target_final = []
                
#         for element in tt: 
#             #print(element)
#             #idx = torch.randperm(element.nelement())
#             #corpus_text = element.view(-1)[idx].view(element.size())
#             corpus_text = element
#             for i in range(CONTEXT_SIZE, len(corpus_text) - CONTEXT_SIZE):
#                 data_context = []
#                 data_target = []
#                 for j in range(CONTEXT_SIZE):
#                     data_context.append(corpus_text[i - CONTEXT_SIZE + j])
#                 for j in range(1, CONTEXT_SIZE + 1):
#                     data_context.append(corpus_text[i + j])

#                 data_target.append(corpus_text[i])
#                 #data.append((data_context, data_target))
#                 data_context_final.append(torch.LongTensor(data_context))
#                 data_target_final.append(torch.LongTensor(data_target))

#         data_context_final = torch.stack(data_context_final).cuda()
#         data_target_final = torch.stack(data_target_final).cuda()        
#         src = torch.randn(5, 7, dtype=torch.double)
#         trg_input = torch.randn(5, 7, dtype=torch.double)
#         src_mask = torch.randn(5, 7, dtype=torch.double)
#         trg_mask = torch.randn(5, 7, dtype=torch.double)

#         preds_emb = model(src, trg_input, src_mask, trg_mask, data_context_final)
#         probs, ix = preds_emb.data.topk(config["number_of_expansion_terms"])
#         preds_token_ids = ix.view(ix.size(0), -1)    
#         preds_token_probs = probs.view(ix.size(0), -1)    
#         preds_strings = ' '.join([' '.join([TRG.vocab.itos[ind] for ind in ex]) for ex in preds_token_ids])
#         preds_strings_with_probs = [(TRG.vocab.itos[ex[0]], math.exp(ex[1].item())) for ex in zip(preds_token_ids, preds_token_probs)]
#         preds_strings = " ".join([tuple[0] for tuple in sorted(preds_strings_with_probs, key = lambda x: x[1], reverse=False)[0:15]])

        query_rm = "#combine:" 
        for idx, item in enumerate(preds_strings_with_probs):
            query_rm+= str(idx) + "=" + str(item[1]) + ":"
        query_rm = query_rm[0:-1] + "(" 
        for idx, item in enumerate(preds_strings_with_probs):
            query_rm+= str(item[0]) + " "
        query_rm = query_rm.strip() + ")"            
        if config["target_cat"] == True:            
            candidate = candidate + " " + " ".join([original_query] * config["target_cat_frequency"])

        if config["query_expansion"] == True:    
            if config["rm"] == False:
                candidate = candidate + " " + preds_strings

        #print (preds_emb)    
        reference = eng_query_dict[key][1]  ###    
        if config["verbose"] == True:
            print("**********************************************************************")    
            print("source query")
            print(opt.text)
            print("**********************************************************************")    
            print("reference translation")
            print(reference)    
            print("**********************************************************************")
            print("candidate translation")
            print(candidate)
            print("**********************************************************************")    
            print("expansion terms")
            print(preds_strings)
            print("**********************************************************************")    
            print("candidate vocabulary distribution")
            query_term_vocabulary_distribution(candidate)
            print("**********************************************************************")    
            print("query vocabulary distribution")
            term_distribution, query_term_ratio, topk_europarl = query_term_distribution(candidate)
            print(term_distribution)
            europarl_vocab+= topk_europarl[0][1]
            clef_vocab+= topk_europarl[0][2]
            ratio+= query_term_ratio
            print(topk_europarl)
            print("**********************************************************************")    
            print("expansion terms vocabulary distribution")
            query_term_vocabulary_distribution(preds_strings)            
            #uery_term_vocabulary_distribution(candidate)
            print("**********************************************************************")


        reference_splitted = set(reference.split())
        candidate_splitted = set(candidate.split())
        uncovered = reference_splitted.difference(candidate_splitted)
        percentage_uncovered = len(uncovered) / (len(reference_splitted) * 1.0)
        sum_percentage_uncovered += percentage_uncovered
        covered = reference_splitted.difference(uncovered)
        str_uncovered = ' '.join(uncovered)
        str_covered = ' '.join(covered)  

        if config["rm"] == True:
            #preds_strings = query_rm
            translation_file.write(key + "\t" + "#combine:0=" + str(config["rm_weight"])+ ":1=" + str(1-config["rm_weight"]) + "(#combine(" + candidate + ") #combine(" + preds_strings + "))\n")
        else:  
            translation_file.write(key + "\t" + candidate +  " \n")  
        nqueries+=1
    print(europarl_vocab / nqueries)
    print(clef_vocab / nqueries)
    print(ratio / nqueries)
    
    print(config['rm_weight'])
    #print("percentage of uncovered terms " + str(sum_percentage_uncovered / config["nqueries"]))            
    translation_file.close()
    evaluate()
# Out:
# **********************************************************************
# source query
# architettura berlino       architettura berlino
# **********************************************************************
# reference translation
# architecture berlin find documents architecture berlin
# **********************************************************************
# candidate translation
# berlin architecture multi level architecture
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'architecture', 'multi', 'berlin', 'level'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	4.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'architecture': [0.2092729313301113, 0.2946829659089366], 'multi': [0.5593873411599553, 0.22332346338000783], 'berlin': [0.6847123855876835, 0.29641639512016565], 'level': [13.062450344924361, 2.9667640950185]}
# [('level', 13.062450344924361, 2.9667640950185)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# guerre radio ruolo radio durante guerre conflitti armati
# **********************************************************************
# reference translation
# war radio role radios play war armed conflict
# **********************************************************************
# candidate translation
# radio wars role radio wars conflicts
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'radio', 'role', 'conflicts', 'wars'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	4.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'radio': [0.38791085180011126, 1.9498189577641305], 'role': [9.268085428393427, 2.7960213177124396], 'conflicts': [1.2317661509468147, 0.29179391722355486], 'wars': [0.381942992541648, 0.30277230222800544]}
# [('role', 9.268085428393427, 2.7960213177124396)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# spionaggio caso ames     mostrano impatto caso spionaggio ames relazioni usa russia
# **********************************************************************
# reference translation
# ames espionage case find documents show impact ames espionage case russian relations
# **********************************************************************
# candidate translation
# european union cooperation cooperation cooperation cooperation european union european union
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'union', 'cooperation'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	3.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'union': [51.92952626615992, 3.526083920508403], 'cooperation': [13.790927031740775, 0.45415845334200816]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# vittorie alberto tomba     riportano vittorie alberto tomba gare sci
# **********************************************************************
# reference translation
# victories alberto tomba find documents report ski races won alberto tomba
# **********************************************************************
# candidate translation
# one major achievements mr one bring us one major battles mrs level openness
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'one', 'mrs', 'level', 'battles', 'major', 'openness', 'bring', 'achievements', 'us', 'mr'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	10.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'one': [38.93988380418881, 46.527551268335706], 'mrs': [13.651279125092735, 0.6260568501222212], 'level': [13.062450344924361, 2.9667640950185], 'battles': [0.07360359752104675, 0.30392792170215815], 'major': [6.188272193742493, 5.9514402918863665], 'openness': [0.8179945756933628, 0.05951440291886367], 'bring': [5.05676607833786, 2.866803010504292], 'achievements': [0.5287523302998439, 0.1516750559825409], 'us': [33.74705053475799, 9.206531445705963], 'mr': [77.4922546138614, 1.1304847505898714]}
# [('mr', 77.4922546138614, 1.1304847505898714)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# conflitto interessi italia recupera   parla problema conflitto interessi presidente consiglio ministri italiano silvio berlusconi
# **********************************************************************
# reference translation
# conflict interests italy find documents discuss problem conflict interests italian prime minister silvio berlusconi
# **********************************************************************
# candidate translation
# conflict interest italy recover speaks conflict interest president italian council ministers mr also mr also mr also mr also mr also mr also mr council
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'italian', 'council', 'conflict', 'president', 'italy', 'mr', 'ministers', 'speaks', 'interest', 'also', 'recover'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	11.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'italian': [1.6733877360730953, 0.8366684992865494], 'council': [40.593776533350926, 8.561695779128762], 'conflict': [3.0177474983629167, 0.8366684992865494], 'president': [61.31736673700651, 11.85578909020101], 'italy': [1.9037471034497768, 0.9109170505008599], 'mr': [77.4922546138614, 1.1304847505898714], 'ministers': [2.8323460040666584, 0.2247679877226987], 'speaks': [0.2896401026774164, 0.36286451488394544], 'interest': [5.4036976298965245, 4.473402984445073], 'also': [65.9790605324341, 25.84398501508228], 'recover': [0.25423080441053447, 0.35246393961657124]}
# [('mr', 77.4922546138614, 1.1304847505898714)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# medaglia oro super vinse medaglia oro super olimpiadi invernali lillehammer
# **********************************************************************
# reference translation
# super gold medal won gold medal super lillehammer olympic winter games
# **********************************************************************
# candidate translation
# gold coin super won gold coin winter olympic super parliament also one two years
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'olympic', 'gold', 'one', 'coin', 'super', 'years', 'won', 'parliament', 'also', 'two', 'winter'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	11.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'olympic': [0.33618940489342974, 1.1397297063830931], 'gold': [0.1663043446691759, 1.5970661132790211], 'one': [38.93988380418881, 46.527551268335706], 'coin': [0.1583471989912249, 0.15398629493084628], 'super': [0.12771218813111354, 1.139440801514555], 'years': [16.191200025494695, 24.846107599151427], 'won': [0.4276965801898662, 9.197864299649819], 'parliament': [49.523683270431434, 0.5024055663878831], 'also': [65.9790605324341, 25.84398501508228], 'two': [16.06547712378307, 34.43832704435585], 'winter': [0.1782400631861024, 1.3035387668442373]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# asma bronchiale     parlano asma bronchiale nuove scoperte fatte medicina malattia respiratoria
# **********************************************************************
# reference translation
# bronchial asthma find documents talk bronchial asthma recent medical discoveries concerning respiratory disease
# **********************************************************************
# candidate translation
# european union asthma also talking economic bee bee among new findings medicine health monitoring
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'monitoring', 'among', 'new', 'medicine', 'bee', 'findings', 'asthma', 'health', 'union', 'also', 'talking', 'economic'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	13.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'monitoring': [3.211901852904921, 0.283704580904486], 'among': [4.454012293233072, 7.528571969236254], 'new': [29.59739906370654, 29.64886213373002], 'medicine': [0.3246515436604008, 0.6725705339568671], 'bee': [0.0970771772710022, 0.1528306754566936], 'findings': [0.4089972878466814, 0.43422401741287425], 'asthma': [0.0373985846863697, 0.07627088529407772], 'health': [10.38327939515826, 6.897314831480346], 'union': [51.92952626615992, 3.526083920508403], 'also': [65.9790605324341, 25.84398501508228], 'talking': [2.9524989038037184, 1.8833708380003507], 'economic': [22.55254013773262, 3.6298007683136073]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# industria automobilistica europa     parlano situazione industria automobilistica europa calo vendite crisi mercato eventuali contromisure
# **********************************************************************
# reference translation
# european car industry find documents report situation european car industry regarding fall sales sales crisis possible countermeasures
# **********************************************************************
# candidate translation
# automotive industry europe speak situation automotive industry europe falling sales market crisis possible market liberalisation
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'industry', 'falling', 'automotive', 'liberalisation', 'possible', 'europe', 'speak', 'crisis', 'situation', 'market', 'sales'}
# count only europarl	1.0
# count only clef	0.0
# count intersection	10.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'industry': [7.583159831087303, 4.27925891278742], 'falling': [0.4829987426516257, 0.6563918613187294], 'automotive': [0.1726700612115367, 0.17189839678021301], 'liberalisation': [1.838100651606681, 0.0], 'possible': [15.13966322415347, 3.183731651290668], 'europe': [38.52253151338028, 1.3644976941057918], 'speak': [3.5986191328533397, 1.284759950389256], 'crisis': [8.891314580542447, 1.153019330335849], 'situation': [15.764299159872623, 1.9703312034303408], 'market': [18.506331560494537, 6.017310601913071], 'sales': [0.5351180468422048, 4.032823059924359]}
# [('europe', 38.52253151338028, 1.3644976941057918)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# ingegneria genetica modo ingegneria genetica influisce catena alimentare uomo
# **********************************************************************
# reference translation
# genetic engineering genetic engineering effect human food chain
# **********************************************************************
# candidate translation
# genetic engineering genetic engineering affects food chain also also process
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'food', 'engineering', 'process', 'chain', 'affects', 'also', 'genetic'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	7.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'food': [6.294500088543138, 4.306704875298547], 'engineering': [0.1925629254064142, 0.7115726912095205], 'process': [11.950439236430709, 2.9942100575296267], 'chain': [0.6158830754734074, 0.9750539313163343], 'affects': [0.8498231584051668, 0.17478744546559474], 'also': [65.9790605324341, 25.84398501508228], 'genetic': [0.35846941279169253, 0.17940992336220551]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# secessione yemen sud quali conseguenze economiche sociali dichiarazione secessione yemen sud
# **********************************************************************
# reference translation
# southern yemen secession social economic consequences declaration secession southern yemen
# **********************************************************************
# candidate translation
# invasion south yemen economic social consequences declaration barbaric yemen
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'declaration', 'barbaric', 'yemen', 'social', 'south', 'invasion', 'consequences', 'economic'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	8.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'declaration': [1.846057797284632, 0.24354680417767996], 'barbaric': [0.14521790862260575, 0.019934435929133947], 'yemen': [0.15715362713953224, 0.036113108567271644], 'social': [19.75003342995828, 2.8379125236504747], 'south': [2.746806688028685, 6.027711177180445], 'invasion': [0.1742614903471269, 0.3943551455546063], 'consequences': [3.338420469184342, 0.35881984672441103], 'economic': [22.55254013773262, 3.6298007683136073]}
# [('economic', 22.55254013773262, 3.6298007683136073)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# sicurezza computer com sicurezza computer accesso rete
# **********************************************************************
# reference translation
# computer security status computer security regard networked access
# **********************************************************************
# candidate translation
# safety computer safety internet access computer
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'computer', 'safety', 'internet', 'access'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	4.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'computer': [0.3437486932874832, 3.1776646490513665], 'safety': [7.642042709104141, 2.9393181325073736], 'internet': [2.033448578000378, 0.3648868489637127], 'access': [6.378447975445521, 1.4488579157189383]}
# [('safety', 7.642042709104141, 2.9393181325073736)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# nuova costituzione sud africa quali state discussioni nuova costituzione sud africa qual forma definitiva
# **********************************************************************
# reference translation
# new constitution south africa find documents discussing new constitution south africa final structure
# **********************************************************************
# candidate translation
# new constitution south africa discussions new constitution south africa form process cooperation
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'discussions', 'new', 'constitution', 'africa', 'south', 'form', 'process', 'cooperation'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	8.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'discussions': [2.6083523532323376, 0.4853601791441309], 'new': [29.59739906370654, 29.64886213373002], 'constitution': [3.1311368242737183, 0.4163119155635075], 'africa': [2.6978702421092864, 0.9681202144714182], 'south': [2.746806688028685, 6.027711177180445], 'form': [4.866590296634832, 2.005577597391998], 'process': [11.950439236430709, 2.9942100575296267], 'cooperation': [13.790927031740775, 0.45415845334200816]}
# [('new', 29.59739906370654, 29.64886213373002)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# animazione computer     discutono impatto animazioni fatte computer industria film
# **********************************************************************
# reference translation
# computer animation find discussions impact computer animation film industry
# **********************************************************************
# candidate translation
# computer eu discussion impact mrs computer made technical industry
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'impact', 'industry', 'eu', 'made', 'technical', 'computer', 'mrs', 'discussion'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	8.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'impact': [4.695113807274987, 1.6909601955539275], 'industry': [7.583159831087303, 4.27925891278742], 'eu': [36.728990877570126, 0.11469523280965474], 'made': [20.436337244681553, 13.79954104572584], 'technical': [3.7012663120989076, 0.7375741293779561], 'computer': [0.3437486932874832, 3.1776646490513665], 'mrs': [13.651279125092735, 0.6260568501222212], 'discussion': [3.602597705692315, 0.6896159212006193]}
# [('eu', 36.728990877570126, 0.11469523280965474)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# pulp fiction premio vinse film pulp fiction quentin tarantino festival cinema cannes
# **********************************************************************
# reference translation
# pulp fiction prize film pulp fiction quentin tarantino win cannes film festival
# **********************************************************************
# candidate translation
# european art prize won film european parliament european parliament european parliament european parliament european parliament
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'prize', 'film', 'art', 'won', 'parliament'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	6.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'prize': [0.5593873411599553, 0.585610168526877], 'film': [0.26537080835966587, 4.256435428172905], 'art': [0.26775795206305114, 4.279547817655959], 'won': [0.4276965801898662, 9.197864299649819], 'parliament': [49.523683270431434, 0.5024055663878831]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# campionati europei     parlano fasi preliminari aspetti organizzativi campionati europei calcio
# **********************************************************************
# reference translation
# european cup find documents regarding preliminary stages organisational issues regarding european football cup
# **********************************************************************
# candidate translation
# european cup talk preliminary stages organisational aspects european euro euro euro euro football championship
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'stages', 'cup', 'championship', 'euro', 'talk', 'preliminary', 'organisational', 'football', 'aspects'}
# count only europarl	1.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'stages': [0.49533231845244974, 0.31143944828415066], 'cup': [0.1663043446691759, 3.5064383894478075], 'championship': [0.0366028701185746, 1.9948881172560855], 'euro': [5.63007842443423, 0.08407131674460838], 'talk': [2.7822159862955673, 3.4177445948065883], 'preliminary': [0.5211930419057905, 0.675748487510787], 'organisational': [0.1822186360250779, 0.0], 'football': [0.4662887367279286, 3.2600025365847456], 'aspects': [3.8277849283783287, 0.3527528444851094]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# guerra civile afghanistan reperisci   descrivono situazione politica porto guerra civile afghanistan dopo destituzione forzata capo comunista najibullah
# **********************************************************************
# reference translation
# civil war afghanistan find documents describing political situation afghanistan led civil war deposition communist leader najibullah
# **********************************************************************
# candidate translation
# civil war afghanistan one two political situation civil war port afghanistan forced removal communist head one one one one one one one one one one
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'one', 'war', 'removal', 'political', 'forced', 'afghanistan', 'port', 'communist', 'head', 'situation', 'two', 'civil'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	12.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'one': [38.93988380418881, 46.527551268335706], 'war': [3.8799042325689075, 4.5597855401379865], 'removal': [0.4280944374737638, 0.2675259082663483], 'political': [20.768548076736007, 5.828077913020567], 'forced': [1.4891798136285297, 1.994021402650471], 'afghanistan': [1.157366838857973, 0.06124783213009271], 'port': [0.7662731287866813, 1.0562361993755611], 'communist': [0.7519502665663695, 0.5263846704765515], 'head': [0.9246203277779061, 4.506049234589886], 'situation': [15.764299159872623, 1.9703312034303408], 'two': [16.06547712378307, 34.43832704435585], 'civil': [4.342214396457861, 1.922084090384466]}
# [('one', 38.93988380418881, 46.527551268335706)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# statistiche divorzio forniscano statistiche percentuale divorzi paesi diversi
# **********************************************************************
# reference translation
# divorce statistics provide statistics divorce rates different countries
# **********************************************************************
# candidate translation
# statistics divorce provide statistics percentage divorce countries also countries
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'percentage', 'statistics', 'provide', 'divorce', 'also', 'countries'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	6.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'percentage': [0.57649520436755, 0.8701814640369775], 'statistics': [1.1506032650317146, 0.6503248590794277], 'provide': [7.030536063753606, 3.2059773261681075], 'divorce': [0.13009933183449884, 0.36113108567271646], 'also': [65.9790605324341, 25.84398501508228], 'countries': [34.36094432381191, 1.5681756264252038]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# snowboard     parlano introduzione nuovo sport invernale tavola neve
# **********************************************************************
# reference translation
# snowboard find documents discuss introduction new winter sport snowboard
# **********************************************************************
# candidate translation
# also talk introduction new winter sport also table time
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'time', 'new', 'talk', 'introduction', 'sport', 'table', 'also', 'winter'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	8.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'time': [29.420750429656028, 26.957713283296936], 'new': [29.59739906370654, 29.64886213373002], 'talk': [2.7822159862955673, 3.4177445948065883], 'introduction': [2.1969679216822713, 0.22101222443170246], 'sport': [1.0817739549174386, 1.1091057903180468], 'table': [1.55084769263265, 1.4208341434707354], 'also': [65.9790605324341, 25.84398501508228], 'winter': [0.1782400631861024, 1.3035387668442373]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# distruzione armi atomiche ucraina     parlano accordo ucraina russia usa smantellamento distruzione arsenale atomico ucraino entro giugno
# **********************************************************************
# reference translation
# destruction ukrainian nuclear weapons find documents report agreement ukraine russia usa removal destruction ukrainian nuclear weapons june
# **********************************************************************
# candidate translation
# destruction nuclear weapons ukraine talking agreement ukraine russia usa dismantling destruction ukrainian nuclear weapons weapons weapons within framework process
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'within', 'agreement', 'ukraine', 'dismantling', 'destruction', 'russia', 'nuclear', 'framework', 'process', 'weapons', 'talking', 'usa', 'ukrainian'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	13.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'within': [14.195150032180686, 3.9187056368517807], 'agreement': [16.6610694777777, 2.7963102225809777], 'ukraine': [1.8166163582762134, 0.24932490154844342], 'dismantling': [0.2633815219401781, 0.07078169279185242], 'destruction': [0.8848345993881512, 0.32732921605375015], 'russia': [4.847891004291647, 1.4488579157189383], 'nuclear': [4.1790929100598655, 1.2281345961557741], 'framework': [9.60705983427414, 0.12422909347141445], 'process': [11.950439236430709, 2.9942100575296267], 'weapons': [1.5142448225140752, 1.5210841328534817], 'talking': [2.9524989038037184, 1.8833708380003507], 'usa': [1.1529904087351, 0.4174675350376602], 'ukrainian': [0.3067479658850111, 0.10718370622766224]}
# [('agreement', 16.6610694777777, 2.7963102225809777)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# tempio solare     parlano ordine tempio solare omicidio suicidio membri
# **********************************************************************
# reference translation
# solar temple find documents order solar temple murder suicide members
# **********************************************************************
# candidate translation
# solar priest speak order solar priest murder suicide two
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'solar', 'priest', 'suicide', 'speak', 'murder', 'two', 'order'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	7.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'solar': [0.16192791454630284, 0.18114335257343456], 'priest': [0.0326242972795991, 0.3088393044673071], 'suicide': [0.20410078663944314, 0.5627866839123613], 'speak': [3.5986191328533397, 1.284759950389256], 'murder': [0.4432130142618707, 2.2300566802461583], 'two': [16.06547712378307, 34.43832704435585], 'order': [15.778622022092936, 3.082326042433769]}
# [('two', 16.06547712378307, 34.43832704435585)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# edouard balladur qual stato impatto politica economica edouard balladur unione europea
# **********************************************************************
# reference translation
# edouard balladur importance european union economic policies edouard balladur
# **********************************************************************
# candidate translation
# european union also made impact economic policy mr also impact european union also work
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'impact', 'made', 'work', 'union', 'also', 'policy', 'mr', 'economic'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'impact': [4.695113807274987, 1.6909601955539275], 'made': [20.436337244681553, 13.79954104572584], 'work': [22.910611693240416, 13.659422184484827], 'union': [51.92952626615992, 3.526083920508403], 'also': [65.9790605324341, 25.84398501508228], 'policy': [30.422952927793954, 3.1860428902389732], 'mr': [77.4922546138614, 1.1304847505898714], 'economic': [22.55254013773262, 3.6298007683136073]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# palmares ayrton senna     risultati sportivi pilota brasiliano ayrton senna
# **********************************************************************
# reference translation
# successes ayrton senna provide record sporting achievements brazilian race car driver ayrton senna
# **********************************************************************
# candidate translation
# process also two way process will also take place
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'way', 'will', 'process', 'also', 'two', 'take', 'place'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	7.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'way': [19.783851299089573, 13.51641427455843], 'will': [104.25094195695893, 57.303413959941025], 'process': [11.950439236430709, 2.9942100575296267], 'also': [65.9790605324341, 25.84398501508228], 'two': [16.06547712378307, 34.43832704435585], 'take': [23.814145584971754, 11.078923898701865], 'place': [11.831877765829239, 8.259501286637832]}
# [('will', 104.25094195695893, 57.303413959941025)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# industria automobilistica nord americana     provvedimenti presi rappresentanti industria automobilistica nord americana aumentare vendite auto mercato nazionale internazionale
# **********************************************************************
# reference translation
# north american car industry find documents discussing efforts automobile industry north america improve sales domestic international markets
# **********************************************************************
# candidate translation
# us car industry measures taken representatives north american car industry increase car sales national market also measures
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'industry', 'north', 'american', 'taken', 'representatives', 'increase', 'national', 'measures', 'market', 'also', 'car', 'sales', 'us'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	13.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'industry': [7.583159831087303, 4.27925891278742], 'north': [1.9602428377632288, 5.62353326609554], 'american': [1.8723163780218703, 10.152405985299943], 'taken': [12.457309416116187, 3.727161709010972], 'representatives': [2.734473112227861, 0.9626310219691929], 'increase': [6.994728908202826, 2.924872889080465], 'national': [14.74817165679828, 7.978685754418728], 'measures': [15.299999709564183, 1.00105536948477], 'market': [18.506331560494537, 6.017310601913071], 'also': [65.9790605324341, 25.84398501508228], 'car': [1.1116132512097547, 5.450479249841175], 'sales': [0.5351180468422048, 4.032823059924359], 'us': [33.74705053475799, 9.206531445705963]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# matrimonio jackson presley     parlano matrimonio presunto michael jackson lisa marie priesley separazione
# **********************************************************************
# reference translation
# marriage jackson presley find documents report presumed marriage michael jackson lisa marie presley separation
# **********************************************************************
# candidate translation
# mrs jackson marriage like one great talk marriage supposed michael jackson will name marie time mr time mr time mr mr president mr mr president mrs mrs jackson
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'name', 'one', 'like', 'time', 'supposed', 'great', 'marriage', 'president', 'will', 'talk', 'mr', 'michael', 'marie', 'jackson', 'mrs'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	15.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'name': [1.9057363898692645, 4.417644344817205], 'one': [38.93988380418881, 46.527551268335706], 'like': [40.93076165281215, 22.664009127082608], 'time': [29.420750429656028, 26.957713283296936], 'supposed': [0.7388209761977503, 1.1105503146607376], 'great': [10.750501668195698, 6.096181631023992], 'marriage': [0.1639172009657906, 0.8323349262584768], 'president': [61.31736673700651, 11.85578909020101], 'will': [104.25094195695893, 57.303413959941025], 'talk': [2.7822159862955673, 3.4177445948065883], 'mr': [77.4922546138614, 1.1304847505898714], 'michael': [0.06644216641089085, 3.6136220956754697], 'marie': [0.0803671713473051, 0.28081553221910427], 'jackson': [0.1257229017116258, 1.7181172531965156], 'mrs': [13.651279125092735, 0.6260568501222212]}
# [('will', 104.25094195695893, 57.303413959941025)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# politica estera difesa comune pesc     definizione politica estera difesa comune parte eu
# **********************************************************************
# reference translation
# ...
# [('commission', 70.15974487162956, 3.2940933110722503)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# importazioni giapponesi riso recupera   discutono motivi conseguenze prima importazione riso giappone
# **********************************************************************
# reference translation
# japanese rice imports find documents discussing reasons consequences first imported rice japan
# **********************************************************************
# candidate translation
# japanese rice imports will recover discuss consequences imports rice also need export
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'need', 'japanese', 'export', 'imports', 'will', 'rice', 'also', 'consequences', 'discuss', 'recover'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	10.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'need': [30.937382395873488, 6.911471170038716], 'japanese': [0.22558507996991084, 2.1748758503553676], 'export': [1.404834069442249, 0.2790821030078753], 'imports': [1.105247534667394, 0.2756152445854172], 'will': [104.25094195695893, 57.303413959941025], 'rice': [0.17465934763102445, 0.9065834774727873], 'also': [65.9790605324341, 25.84398501508228], 'consequences': [3.338420469184342, 0.35881984672441103], 'discuss': [2.491382311766458, 1.1836432464008955], 'recover': [0.25423080441053447, 0.35246393961657124]}
# [('will', 104.25094195695893, 57.303413959941025)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# fast food giappone quali catene nord americane fast food alto numero ristoranti franchising giappone
# **********************************************************************
# reference translation
# fast food japan north american fast food chains large number franchise restaurants japan
# **********************************************************************
# candidate translation
# fast food japan north american food chain fast food high number catering also two way
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'north', 'american', 'catering', 'food', 'way', 'high', 'fast', 'japan', 'chain', 'number', 'also', 'two'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	12.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'north': [1.9602428377632288, 5.62353326609554], 'american': [1.8723163780218703, 10.152405985299943], 'catering': [0.087528602457461, 0.11209508899281118], 'food': [6.294500088543138, 4.306704875298547], 'way': [19.783851299089573, 13.51641427455843], 'high': [7.808347053773316, 15.822741840098667], 'fast': [0.6258295075708461, 1.8267454837668688], 'japan': [0.7996931406340755, 2.258080452494361], 'chain': [0.6158830754734074, 0.9750539313163343], 'number': [11.34131973478356, 5.237556361728541], 'also': [65.9790605324341, 25.84398501508228], 'two': [16.06547712378307, 34.43832704435585]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# incidenti petroliferi uccelli recupera   descrivono danni ferite riportati uccelli causa perdite accidentali petrolio inquinamento
# **********************************************************************
# reference translation
# oil accidents birds find documents describing damage injury birds caused accidental oil spills pollution
# **********************************************************************
# candidate translation
# oil accidents birds recover describe damage injuries birds result accidental oil losses also one way another
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'one', 'damage', 'way', 'oil', 'another', 'birds', 'losses', 'result', 'accidents', 'describe', 'injuries', 'also', 'accidental', 'recover'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	14.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'one': [38.93988380418881, 46.527551268335706], 'damage': [1.8842520965387968, 2.6668808414758765], 'way': [19.783851299089573, 13.51641427455843], 'oil': [2.3370136856142087, 2.5955213389469476], 'another': [7.816304199451268, 11.349338855653594], 'birds': [0.2005200710843652, 0.6119005115638507], 'losses': [0.6500988018885967, 1.2168673062827853], 'result': [7.743098459214118, 2.4392238050677957], 'accidents': [0.9747503455489975, 0.40388900621636603], 'describe': [0.3648351293340534, 0.47380398440260396], 'injuries': [0.17625077676661466, 1.1550416644156163], 'also': [65.9790605324341, 25.84398501508228], 'accidental': [0.0588828780168374, 0.10516137214789502], 'recover': [0.25423080441053447, 0.35246393961657124]}
# [('also', 65.9790605324341, 25.84398501508228)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# danni strato ozono quali buchi ozono effetto inquinamento
# **********************************************************************
# reference translation
# damages ozone layer holes ozone layer effect pollution
# **********************************************************************
# candidate translation
# ozone layer ozone hole effect will also result cross border ozone layer
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'cross', 'ozone', 'hole', 'effect', 'result', 'border', 'will', 'layer', 'also'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'cross': [2.673600947791536, 1.9995105951526964], 'ozone': [0.1798314923216926, 0.11873990096918917], 'hole': [0.0915071752964365, 0.8288680678360187], 'effect': [3.900990668615478, 1.8484133489072319], 'result': [7.743098459214118, 2.4392238050677957], 'border': [3.9451528271281058, 1.1807541977155136], 'will': [104.25094195695893, 57.303413959941025], 'layer': [0.0986686064065924, 0.21610084166655352], 'also': [65.9790605324341, 25.84398501508228]}
# [('will', 104.25094195695893, 57.303413959941025)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# competitivita imprenditoria europea quali fattori danneggiano competitivita imprese europee mercati mondiali
# **********************************************************************
# reference translation
# competitiveness european industry factors damage competitiveness european industry world markets
# **********************************************************************
# candidate translation
# competitiveness european entrepreneurship factors damage competitiveness european companies inter alia multi level governance markets
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'european', 'damage', 'companies', 'level', 'inter', 'entrepreneurship', 'governance', 'markets', 'alia', 'multi', 'factors', 'competitiveness'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	12.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'european': [117.65952813887415, 1.181620912321128], 'damage': [1.8842520965387968, 2.6668808414758765], 'companies': [5.5139040975361455, 4.415622010737438], 'level': [13.062450344924361, 2.9667640950185], 'inter': [0.5908180665878617, 0.09013831898391002], 'entrepreneurship': [0.2506500888554565, 0.015889767769599522], 'governance': [1.7839920609966142, 0.03351296475042809], 'markets': [4.008014277983919, 1.4139004266258193], 'alia': [0.1726700612115367, 0.0031779535539199046], 'multi': [0.5593873411599553, 0.22332346338000783], 'factors': [1.2922404580992424, 0.4784264622992147], 'competitiveness': [2.746408830744788, 0.07395964634577233]}
# [('european', 117.65952813887415, 1.181620912321128)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# pena morte     riferiscono azioni specifiche amesty international pena morte
# **********************************************************************
# reference translation
# ai death penalty find reports specific actions amnesty international death penalty
# **********************************************************************
# candidate translation
# death penalty relate specific actions international international judicial action
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'international', 'relate', 'actions', 'action', 'penalty', 'specific', 'death', 'judicial'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	8.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'international': [14.793925244446498, 3.736117759935655], 'relate': [0.6429373707784408, 0.200211073896954], 'actions': [3.725535606416658, 0.856025125478607], 'action': [12.407179398345097, 3.3053606009452388], 'penalty': [1.078591096646258, 1.1726648613964448], 'specific': [7.205991125952425, 0.9672534998658037], 'death': [2.287281525127015, 4.173519730902449], 'judicial': [1.4577490882006232, 0.3215511186829867]}
# [('international', 14.793925244446498, 3.736117759935655)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# **********************************************************************
# source query
# meraviglie mondo antico cerca informazioni esistenza scoperta rovine sette meraviglie mondo antico
# **********************************************************************
# reference translation
# wonders ancient world look information existence discovery remains seven wonders ancient world
# **********************************************************************
# candidate translation
# wonder old world seeking information existence discovered ruins seven million us world one one world one one two years time
# **********************************************************************
# expansion terms
# trade european european budget trade budget union states states european will commission health federal federal
# **********************************************************************
# candidate vocabulary distribution
# {'world', 'seeking', 'discovered', 'one', 'seven', 'ruins', 'time', 'million', 'information', 'old', 'existence', 'years', 'two', 'us', 'wonder'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	15.0
# count others	0.0
# **********************************************************************
# query vocabulary distribution
# {'world': [14.991262457259683, 11.830076556901114], 'seeking': [1.4430283686964138, 1.8134558598141128], 'discovered': [0.28446795798674823, 1.1741093857391356], 'one': [38.93988380418881, 46.527551268335706], 'seven': [1.078591096646258, 4.89607080711642], 'ruins': [0.05530216246175945, 0.1161397571523456], 'time': [29.420750429656028, 26.957713283296936], 'million': [7.067536791156078, 17.119635794966527], 'information': [11.929750657668036, 5.814788289067811], 'old': [2.695085241122004, 13.713158490032926], 'existence': [1.2417125830442535, 0.3227067381571394], 'years': [16.191200025494695, 24.846107599151427], 'two': [16.06547712378307, 34.43832704435585], 'us': [33.74705053475799, 9.206531445705963], 'wonder': [1.0153317885065476, 0.8765373711448173]}
# [('one', 38.93988380418881, 46.527551268335706)]
# **********************************************************************
# expansion terms vocabulary distribution
# {'european', 'commission', 'trade', 'budget', 'will', 'states', 'union', 'federal', 'health'}
# count only europarl	0.0
# count only clef	0.0
# count intersection	9.0
# count others	0.0
# **********************************************************************
# 64.78602976664754
# 18.3479090654592
# 0.5
# MAP:	0.1915
